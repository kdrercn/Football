# %% [markdown]
# ### Libraries

# %%
from mobfot import MobFot
client = MobFot()

# %% [markdown]
# ### Select Player

# %%
# player = client.get_player("661761") 
# playername = "Riccardo Orsolini"

# player = client.get_player("94267") 
# playername = "Dusan Tadic"

# player = client.get_player("1387389") 
# playername = "Arthur Vermeeren"

player = client.get_player("765466") 
playername = "Sebastian Szymanski"

# %% [markdown]
# ### Recent Matches

# %%
res = list(player["recentMatches"].values())[0]
last_one = res[0]
res
# Out:
# [{'htName': 'Faroe Islands',
#   'atName': 'Poland',
#   'date': {'utcTime': '2023-10-12T20:45:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4044731,
#    'opponentName': 'Faroe Islands',
#    'opponentId': 8269,
#    'homeTeamScore': 0,
#    'awayTeamScore': 2,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 59,
#   'tournament': 'EURO Qualification Grp. E',
#   'goals': 1,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '8.1', 'bgcolor': '#1ec853'}},
#  {'htName': 'Kasımpaşa',
#   'atName': 'Fenerbahçe',
#   'date': {'utcTime': '2023-10-08T18:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4257174,
#    'opponentName': 'Kasımpaşa',
#    'opponentId': 4685,
#    'homeTeamScore': 0,
#    'awayTeamScore': 2,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 84,
#   'tournament': 'Super Lig',
#   'goals': 0,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '7.4', 'bgcolor': '#1ec853'}},
#  {'htName': 'Spartak Trnava',
#   'atName': 'Fenerbahçe',
#   'date': {'utcTime': '2023-10-05T21:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4315328,
#    'opponentName': 'Spartak Trnava',
#    'opponentId': 4662,
#    'homeTeamScore': 1,
#    'awayTeamScore': 2,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 27,
#   'tournament': 'Europa Conference League Grp. H',
#   'goals': 0,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '6.2', 'bgcolor': '#f08022'}},
#  {'htName': 'Fenerbahçe',
#   'atName': 'Rizespor',
#   'date': {'utcTime': '2023-10-01T15:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4257169,
#    'opponentName': 'Rizespor',
#    'opponentId': 2166,
#    'homeTeamScore': 5,
#    'awayTeamScore': 0,
#    'highLightHomeTeam': True},
#   'minutesPlayed': 77,
#   'tournament': 'Super Lig',
#   'goals': 1,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '8.7', 'bgcolor': '#0e87e0'}},
#  {'htName': 'Fenerbahçe',
#   'atName': 'Başakşehir',
#   'date': {'utcTime': '2023-09-28T19:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4257125,
#    'opponentName': 'Başakşehir',
#    'opponentId': 1933,
#    'homeTeamScore': 4,
#    'awayTeamScore': 0,
#    'highLightHomeTeam': True},
#   'minutesPlayed': 90,
#   'tournament': 'Super Lig',
#   'goals': 2,
#   'assists': 0,
#   'yellowCards': 1,
#   'redCards': 0,
#   'ratingProps': {'num': '9.1', 'bgcolor': '#0e87e0'}},
#  {'htName': 'Alanyaspor',
#   'atName': 'Fenerbahçe',
#   'date': {'utcTime': '2023-09-24T19:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4257141,
#    'opponentName': 'Alanyaspor',
#    'opponentId': 4678,
#    'homeTeamScore': 0,
#    'awayTeamScore': 1,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 89,
#   'tournament': 'Super Lig',
#   'goals': 0,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '6.9', 'bgcolor': '#f08022'}},
#  {'htName': 'Fenerbahçe',
#   'atName': 'Nordsjælland',
#   'date': {'utcTime': '2023-09-21T18:45:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4315290,
#    'opponentName': 'Nordsjælland',
#    'opponentId': 10202,
#    'homeTeamScore': 3,
#    'awayTeamScore': 1,
#    'highLightHomeTeam': True},
#   'minutesPlayed': 12,
#   'tournament': 'Europa Conference League Grp. H',
#   'goals': 0,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '6.7', 'bgcolor': '#f08022'}},
#  {'htName': 'Fenerbahçe',
#   'atName': 'Antalyaspor',
#   'date': {'utcTime': '2023-09-17T16:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4257117,
#    'opponentName': 'Antalyaspor',
#    'opponentId': 1931,
#    'homeTeamScore': 3,
#    'awayTeamScore': 2,
#    'highLightHomeTeam': True},
#   'minutesPlayed': 89,
#   'tournament': 'Super Lig',
#   'goals': 1,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '7.9', 'bgcolor': '#1ec853'}},
#  {'htName': 'Albania',
#   'atName': 'Poland',
#   'date': {'utcTime': '2023-09-10T20:45:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4044729,
#    'opponentName': 'Albania',
#    'opponentId': 10024,
#    'homeTeamScore': 2,
#    'awayTeamScore': 0,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 61,
#   'tournament': 'EURO Qualification Grp. E',
#   'goals': 0,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '6.6', 'bgcolor': '#f08022'}},
#  {'htName': 'Poland',
#   'atName': 'Faroe Islands',
#   'date': {'utcTime': '2023-09-07T20:45:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4044726,
#    'opponentName': 'Faroe Islands',
#    'opponentId': 8269,
#    'homeTeamScore': 2,
#    'awayTeamScore': 0,
#    'highLightHomeTeam': True},
#   'minutesPlayed': 31,
#   'tournament': 'EURO Qualification Grp. E',
#   'goals': 0,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '7.2', 'bgcolor': '#1ec853'}},
#  {'htName': 'Ankaragücü',
#   'atName': 'Fenerbahçe',
#   'date': {'utcTime': '2023-09-03T20:45:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4257108,
#    'opponentName': 'Ankaragücü',
#    'opponentId': 9742,
#    'homeTeamScore': 0,
#    'awayTeamScore': 1,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 83,
#   'tournament': 'Super Lig',
#   'goals': 0,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': '7.1', 'bgcolor': '#1ec853'}},
#  {'htName': 'FC Twente',
#   'atName': 'Fenerbahçe',
#   'date': {'utcTime': '2023-08-31T19:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4287967,
#    'opponentName': 'FC Twente',
#    'opponentId': 8611,
#    'homeTeamScore': 0,
#    'awayTeamScore': 1,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 29,
#   'tournament': 'Europa Conference League Qualification',
#   'goals': 0,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': 0, 'bgcolor': '#989898'}},
#  {'htName': 'Fenerbahçe',
#   'atName': 'FC Twente',
#   'date': {'utcTime': '2023-08-24T19:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4287945,
#    'opponentName': 'FC Twente',
#    'opponentId': 8611,
#    'homeTeamScore': 5,
#    'awayTeamScore': 1,
#    'highLightHomeTeam': True},
#   'minutesPlayed': 84,
#   'tournament': 'Europa Conference League Qualification',
#   'goals': 1,
#   'assists': 1,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': 0, 'bgcolor': '#989898'}},
#  {'htName': 'Samsunspor',
#   'atName': 'Fenerbahçe',
#   'date': {'utcTime': '2023-08-21T20:00:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4257086,
#    'opponentName': 'Samsunspor',
#    'opponentId': 9750,
#    'homeTeamScore': 0,
#    'awayTeamScore': 2,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 5,
#   'tournament': 'Super Lig',
#   'goals': 1,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': 0, 'bgcolor': '#989898'}},
#  {'htName': 'Maribor',
#   'atName': 'Fenerbahçe',
#   'date': {'utcTime': '2023-08-17T20:15:00.000Z', 'timezone': None},
#   'versus': {'matchId': 4268994,
#    'opponentName': 'Maribor',
#    'opponentId': 8340,
#    'homeTeamScore': 0,
#    'awayTeamScore': 3,
#    'highLightHomeTeam': False},
#   'minutesPlayed': 90,
#   'tournament': 'Europa Conference League Qualification',
#   'goals': 1,
#   'assists': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'ratingProps': {'num': 0, 'bgcolor': '#989898'}}]

# %% [markdown]
# ### Get this season's date, league, opposition team's name, goal, assisst, rating data

# %%
for i in range(len(list(player["recentMatches"].values())[0])):
    # print(res[i])    
    team = res[i]
    lig = team["tournament"]
    date = team["date"]
    dateY = date["utcTime"][0:10]
    opp = team["versus"]
    if i==0:
      oppName1 = opp["opponentName"]
    oppName = opp["opponentName"]
    min = team["minutesPlayed"]
    goals = team["goals"]
    assists = team["assists"]
    rat = team["ratingProps"]
    ratNum = rat["num"]
    matchId = opp["matchId"]
    y = client.get_match_details(matchId)

    if i==0:  
      last = client.get_match_details(matchId)

    if int(dateY[5:7]) > 6:
        print(str(dateY) + " - " + 
              lig + " : " + oppName + " - " +
                str(min) + " Dakika " + " - " +
                  "Gol: " + str(goals) + " - " +
                   "Asist: " + str(assists) + " - " +
                    "Rating: " + str(ratNum))
# Out:
# 2023-10-12 - EURO Qualification Grp. E : Faroe Islands - 59 Dakika  - Gol: 1 - Asist: 0 - Rating: 8.1
# 2023-10-08 - Super Lig : Kasımpaşa - 84 Dakika  - Gol: 0 - Asist: 0 - Rating: 7.4
# 2023-10-05 - Europa Conference League Grp. H : Spartak Trnava - 27 Dakika  - Gol: 0 - Asist: 0 - Rating: 6.2
# 2023-10-01 - Super Lig : Rizespor - 77 Dakika  - Gol: 1 - Asist: 0 - Rating: 8.7
# 2023-09-28 - Super Lig : Başakşehir - 90 Dakika  - Gol: 2 - Asist: 0 - Rating: 9.1
# 2023-09-24 - Super Lig : Alanyaspor - 89 Dakika  - Gol: 0 - Asist: 0 - Rating: 6.9
# 2023-09-21 - Europa Conference League Grp. H : Nordsjælland - 12 Dakika  - Gol: 0 - Asist: 0 - Rating: 6.7
# 2023-09-17 - Super Lig : Antalyaspor - 89 Dakika  - Gol: 1 - Asist: 0 - Rating: 7.9
# 2023-09-10 - EURO Qualification Grp. E : Albania - 61 Dakika  - Gol: 0 - Asist: 0 - Rating: 6.6
# 2023-09-07 - EURO Qualification Grp. E : Faroe Islands - 31 Dakika  - Gol: 0 - Asist: 0 - Rating: 7.2
# 2023-09-03 - Super Lig : Ankaragücü - 83 Dakika  - Gol: 0 - Asist: 0 - Rating: 7.1
# 2023-08-31 - Europa Conference League Qualification : FC Twente - 29 Dakika  - Gol: 0 - Asist: 0 - Rating: 0
# 2023-08-24 - Europa Conference League Qualification : FC Twente - 84 Dakika  - Gol: 1 - Asist: 1 - Rating: 0
# 2023-08-21 - Super Lig : Samsunspor - 5 Dakika  - Gol: 1 - Asist: 0 - Rating: 0
# 2023-08-17 - Europa Conference League Qualification : Maribor - 90 Dakika  - Gol: 1 - Asist: 0 - Rating: 0

# %% [markdown]
# ### Get Last Game

# %%
gameD = list(last.values())
gameDe = list(gameD[5].values())
gameDe
# Out:
# [{'matchId': 4044731,
#   'highlights': None,
#   'playerOfTheMatch': {'id': 402419,
#    'name': {'firstName': 'Przemyslaw',
#     'lastName': 'Frankowski',
#     'fullName': 'Przemyslaw Frankowski'},
#    'teamName': 'Poland',
#    'teamId': 8568,
#    'rating': {'num': '8.5',
#     'isTop': {'isTopRating': True, 'isMatchFinished': True}},
#    'minutesPlayed': 90,
#    'shotmap': [{'id': 2603687939,
#      'eventType': 'AttemptSaved',
#      'teamId': 8568,
#      'playerId': 402419,
#      'playerName': 'Przemyslaw Frankowski',
#      'x': 93.5,
#      'y': 43.790573243599994,
#      'min': 15,
#      'minAdded': None,
#      'isBlocked': True,
#      'isOnTarget': True,
#      'blockedX': 96.79824561320001,
#      'blockedY': 41.3678125,
#      'goalCrossedY': 33.8475,
#      'goalCrossedZ': 1.2199999940000001,
#      'expectedGoals': 0.06017984449863434,
#      'expectedGoalsOnTarget': None,
#      'shotType': 'RightFoot',
#      'situation': 'RegularPlay',
#      'period': 'FirstHalf',
#      'isOwnGoal': False,
#      'onGoalShot': {'x': 1.0403439153439162,
#       'y': 0.32275132116402117,
#       'zoomRatio': 1},
#      'isSavedOffLine': False,
#      'teamColor': '#ff2600'},
#     {'id': 2603693893,
#      'eventType': 'AttemptSaved',
#      'teamId': 8568,
#      'playerId': 402419,
#      'playerName': 'Przemyslaw Frankowski',
#      'x': 95.15789473550001,
#      'y': 45.9625477669,
#      'min': 30,
#      'minAdded': None,
#      'isBlocked': True,
#      'isOnTarget': True,
#      'blockedX': 96.605263157,
#      'blockedY': 44.2810191037,
#      'goalCrossedY': 34.7625,
#      'goalCrossedZ': 1.2199999940000001,
#      'expectedGoals': 0.03461189940571785,
#      'expectedGoalsOnTarget': None,
#      'shotType': 'LeftFoot',
#      'situation': 'RegularPlay',
#      'period': 'FirstHalf',
#      'isOwnGoal': False,
#      'onGoalShot': {'x': 0.7982804232804226,
#       'y': 0.32275132116402117,
#       'zoomRatio': 1},
#      'isSavedOffLine': False,
#      'teamColor': '#ff2600'},
#     {'id': 2603697537,
#      'eventType': 'AttemptSaved',
#      'teamId': 8568,
#      'playerId': 402419,
#      'playerName': 'Przemyslaw Frankowski',
#      'x': 93.7,
#      'y': 41.5990625,
#      'min': 39,
#      'minAdded': None,
#      'isBlocked': True,
#      'isOnTarget': True,
#      'blockedX': 96.79824561320001,
#      'blockedY': 39.545000001,
#      'goalCrossedY': 34.68625,
#      'goalCrossedZ': 1.2199999940000001,
#      'expectedGoals': 0.0764651969075203,
#      'expectedGoalsOnTarget': None,
#      'shotType': 'RightFoot',
#      'situation': 'RegularPlay',
#      'period': 'FirstHalf',
#      'isOwnGoal': False,
#      'onGoalShot': {'x': 0.8184523809523807,
#       'y': 0.32275132116402117,
#       'zoomRatio': 1},
#      'isSavedOffLine': False,
#      'teamColor': '#ff2600'},
#     {'id': 2603706853,
#      'eventType': 'AttemptSaved',
#      'teamId': 8568,
#      'playerId': 402419,
#      'playerName': 'Przemyslaw Frankowski',
#      'x': 77.9800970888,
#      'y': 47.714140124400004,
#      'min': 61,
#      'minAdded': None,
#      'isBlocked': True,
#      'isOnTarget': True,
#      'blockedX': 91.3,
#      'blockedY': 40.805714286,
#      'goalCrossedY': 32.0175,
#      'goalCrossedZ': 1.2199999940000001,
#      'expectedGoals': 0.014545807614922523,
#      'expectedGoalsOnTarget': None,
#      'shotType': 'RightFoot',
#      'situation': 'RegularPlay',
#      'period': 'SecondHalf',
#      'isOwnGoal': False,
#      'onGoalShot': {'x': 1.5244708994709,
#       'y': 0.32275132116402117,
#       'zoomRatio': 1},
#      'isSavedOffLine': False,
#      'teamColor': '#ff2600'}],
#    'pageUrl': '/players/402419/przemyslaw-frankowski',
#    'isHomeTeam': False,
#    'stats': [{'title': 'Top stats',
#      'key': 'top_stats',
#      'stats': {'FotMob rating': {'key': 'rating_title', 'value': 8.5},
#       'Minutes played': {'key': 'minutes_played', 'value': 90},
#       'Goals': {'key': 'goals', 'value': 0},
#       'Assists': {'key': 'assists', 'value': 1},
#       'Total shots': {'key': 'total_shots', 'value': 4},
#       'Shotmap': {'key': None, 'value': True},
#       'Accurate passes': {'key': 'accurate_passes', 'value': '48/56 (86%)'},
#       'Chances created': {'key': 'chances_created', 'value': 4},
#       'Expected goals (xG)': {'key': 'expected_goals', 'value': '0.19'},
#       'Expected assists (xA)': {'key': 'expected_assists', 'value': '0.73'},
#       'xG + xA': {'key': 'xg_and_xa', 'value': '0.92'}}},
#     {'title': 'Attack',
#      'key': 'attack',
#      'stats': {'Blocked shots': {'key': 'blocked_shots', 'value': 4},
#       'Touches': {'key': 'touches', 'value': 82},
#       'Successful dribbles': {'key': 'dribbles_succeeded',
#        'value': '1/4 (25%)'},
#       'Passes into final third': {'key': 'passes_into_final_third',
#        'value': 3},
#       'Accurate crosses': {'key': 'accurate_crosses', 'value': '2/5 (40%)'},
#       'Accurate long balls': {'key': 'long_balls_accurate',
#        'value': '3/3 (100%)'},
#       'Dispossessed': {'key': 'dispossessed', 'value': 1},
#       'xG Non-penalty': {'key': 'expected_goals_non_penalty',
#        'value': '0.19'}}},
#     {'title': 'Defense',
#      'key': 'defense',
#      'stats': {'Tackles won': {'key': 'tackles_succeeded',
#        'value': '3/3 (100%)'},
#       'Clearances': {'key': 'clearances', 'value': 1},
#       'Defensive actions': {'key': 'defensive_actions', 'value': 5},
#       'Recoveries': {'key': 'recoveries', 'value': 7},
#       'Dribbled past': {'key': 'dribbled_past', 'value': 1}}},
#     {'title': 'Duels',
#      'key': 'duels',
#      'stats': {'Duels won': {'key': 'duel_won', 'value': 6},
#       'Duels lost': {'key': 'duel_lost', 'value': 6},
#       'Ground duels won': {'key': 'ground_duels_won', 'value': '6/12 (50%)'},
#       'Aerial duels won': {'key': 'aerials_won', 'value': 0},
#       'Was fouled': {'key': 'was_fouled', 'value': 2},
#       'Fouls committed': {'key': 'fouls', 'value': 1}}}],
#    'role': 'Defender',
#    'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#     'away': {'id': 8269, 'color': '#ff2600'}}},
#   'matchesInRound': [{'id': '4044711',
#     'home': {'id': '5795', 'name': 'Latvia', 'shortName': 'LVA'},
#     'away': {'id': '6583', 'name': 'Armenia', 'shortName': 'ARM'},
#     'matchDate': '202310121800',
#     'status': {'utcTime': '2023-10-12T16:00:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '2 - 0',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 2,
#     'awayScore': 0},
#    {'id': '4044730',
#     'home': {'id': '10024', 'name': 'Albania', 'shortName': 'ALB'},
#     'away': {'id': '8496', 'name': 'Czechia', 'shortName': 'CZE'},
#     'matchDate': '202310122045',
#     'status': {'utcTime': '2023-10-12T18:45:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '3 - 0',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 3,
#     'awayScore': 0},
#    {'id': '4044653',
#     'home': {'id': '10045', 'name': 'Andorra', 'shortName': 'AND'},
#     'away': {'id': '430156', 'name': 'Kosovo', 'shortName': 'KOS'},
#     'matchDate': '202310122045',
#     'status': {'utcTime': '2023-10-12T18:45:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '0 - 3',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 0,
#     'awayScore': 3},
#    {'id': '4044652',
#     'home': {'id': '10057', 'name': 'Belarus', 'shortName': 'BLR'},
#     'away': {'id': '9730', 'name': 'Romania', 'shortName': 'ROU'},
#     'matchDate': '202310122045',
#     'status': {'utcTime': '2023-10-12T18:45:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '0 - 0',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 0,
#     'awayScore': 0},
#    {'id': '4044710',
#     'home': {'id': '10155', 'name': 'Croatia', 'shortName': 'CRO'},
#     'away': {'id': '6595', 'name': 'Türkiye', 'shortName': 'TUR'},
#     'matchDate': '202310122045',
#     'status': {'utcTime': '2023-10-12T18:45:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '0 - 1',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 0,
#     'awayScore': 1},
#    {'id': '4044574',
#     'home': {'id': '5793', 'name': 'Cyprus', 'shortName': 'CYP'},
#     'away': {'id': '8492', 'name': 'Norway', 'shortName': 'NOR'},
#     'matchDate': '202310122045',
#     'status': {'utcTime': '2023-10-12T18:45:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '0 - 4',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 0,
#     'awayScore': 4},
#    {'id': '4044731',
#     'home': {'id': '8269', 'name': 'Faroe Islands', 'shortName': 'FRO'},
#     'away': {'id': '8568', 'name': 'Poland', 'shortName': 'POL'},
#     'matchDate': '202310122045',
#     'status': {'utcTime': '2023-10-12T18:45:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '0 - 2',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 0,
#     'awayScore': 2},
#    {'id': '4044654',
#     'home': {'id': '8567', 'name': 'Israel', 'shortName': 'ISR'},
#     'away': {'id': '6717', 'name': 'Switzerland', 'shortName': 'SUI'},
#     'matchDate': '202310122045',
#     'status': {'utcTime': '2023-10-12T18:45:00.000Z',
#      'cancelled': True,
#      'started': False,
#      'finished': True,
#      'reason': {'short': 'PP',
#       'shortKey': 'postponed_short',
#       'long': 'Postponed',
#       'longKey': 'postponed'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 0,
#     'awayScore': 0},
#    {'id': '4044562',
#     'home': {'id': '6720', 'name': 'Spain', 'shortName': 'ESP'},
#     'away': {'id': '8498', 'name': 'Scotland', 'shortName': 'SCO'},
#     'matchDate': '202310122045',
#     'status': {'utcTime': '2023-10-12T18:45:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '2 - 0',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'roundId': 7,
#     'roundName': '7',
#     'homeScore': 2,
#     'awayScore': 0},
#    {'id': '4044771',
#     'home': {'id': '8261', 'name': 'Estonia', 'shortName': 'EST'},
#     'away': {'id': '8566', 'name': 'Azerbaijan', 'shortName': 'AZE'},
#     'matchDate': '202310131800',
#     'status': {'utcTime': '2023-10-13T16:00:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044770',
#     'home': {'id': '8255', 'name': 'Austria', 'shortName': 'AUT'},
#     'away': {'id': '8263', 'name': 'Belgium', 'shortName': 'BEL'},
#     'matchDate': '202310132045',
#     'status': {'utcTime': '2023-10-13T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044597',
#     'home': {'id': '8536', 'name': 'Iceland', 'shortName': 'ISL'},
#     'away': {'id': '5792', 'name': 'Luxembourg', 'shortName': 'LUX'},
#     'matchDate': '202310132045',
#     'status': {'utcTime': '2023-10-13T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044617',
#     'home': {'id': '5791', 'name': 'Ireland', 'shortName': 'IRL'},
#     'away': {'id': '6383', 'name': 'Greece', 'shortName': 'GRE'},
#     'matchDate': '202310132045',
#     'status': {'utcTime': '2023-10-13T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044595',
#     'home': {'id': '5799', 'name': 'Liechtenstein', 'shortName': 'LIE'},
#     'away': {'id': '10106',
#      'name': 'Bosnia and Herzegovina',
#      'shortName': 'BIH'},
#     'matchDate': '202310132045',
#     'status': {'utcTime': '2023-10-13T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044673',
#     'home': {'id': '6708', 'name': 'Netherlands', 'shortName': 'NED'},
#     'away': {'id': '6723', 'name': 'France', 'shortName': 'FRA'},
#     'matchDate': '202310132045',
#     'status': {'utcTime': '2023-10-13T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044596',
#     'home': {'id': '8361', 'name': 'Portugal', 'shortName': 'POR'},
#     'away': {'id': '8497', 'name': 'Slovakia', 'shortName': 'SVK'},
#     'matchDate': '202310132045',
#     'status': {'utcTime': '2023-10-13T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044796',
#     'home': {'id': '10259', 'name': 'Northern Ireland', 'shortName': 'NIR'},
#     'away': {'id': '6035', 'name': 'San Marino', 'shortName': 'SMR'},
#     'matchDate': '202310141500',
#     'status': {'utcTime': '2023-10-14T13:00:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044690',
#     'home': {'id': '6718', 'name': 'Ukraine', 'shortName': 'UKR'},
#     'away': {'id': '8260', 'name': 'North Macedonia', 'shortName': 'MKD'},
#     'matchDate': '202310141500',
#     'status': {'utcTime': '2023-10-14T13:00:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044750',
#     'home': {'id': '10150', 'name': 'Bulgaria', 'shortName': 'BGR'},
#     'away': {'id': '8254', 'name': 'Lithuania', 'shortName': 'LTU'},
#     'matchDate': '202310141800',
#     'status': {'utcTime': '2023-10-14T16:00:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044797',
#     'home': {'id': '5787', 'name': 'Slovenia', 'shortName': 'SVN'},
#     'away': {'id': '7871', 'name': 'Finland', 'shortName': 'FIN'},
#     'matchDate': '202310141800',
#     'status': {'utcTime': '2023-10-14T16:00:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044798',
#     'home': {'id': '8238', 'name': 'Denmark', 'shortName': 'DEN'},
#     'away': {'id': '8265', 'name': 'Kazakhstan', 'shortName': 'KAZ'},
#     'matchDate': '202310142045',
#     'status': {'utcTime': '2023-10-14T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044751',
#     'home': {'id': '8565', 'name': 'Hungary', 'shortName': 'HUN'},
#     'away': {'id': '8205', 'name': 'Serbia', 'shortName': 'SER'},
#     'matchDate': '202310142045',
#     'status': {'utcTime': '2023-10-14T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'},
#    {'id': '4044691',
#     'home': {'id': '8204', 'name': 'Italy', 'shortName': 'ITA'},
#     'away': {'id': '8495', 'name': 'Malta', 'shortName': 'MAL'},
#     'matchDate': '202310142045',
#     'status': {'utcTime': '2023-10-14T18:45:00.000Z',
#      'started': False,
#      'cancelled': False,
#      'finished': False},
#     'roundId': 7,
#     'roundName': '7'}],
#   'events': {'ongoing': False,
#    'events': [{'reactKey': '4Goal765466undefinedfalse',
#      'timeStr': 4,
#      'type': 'Goal',
#      'time': 4,
#      'overloadTime': None,
#      'eventId': 10644953,
#      'player': {'id': 765466,
#       'name': 'Sebastian Szymanski',
#       'profileUrl': '/players/765466/sebastian-szymanski'},
#      'profileUrl': '/players/765466/sebastian-szymanski',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'ownGoal': None,
#      'goalDescription': None,
#      'goalDescriptionKey': None,
#      'suffix': None,
#      'suffixKey': None,
#      'isPenaltyShootoutEvent': False,
#      'nameStr': 'Sebastian Szymanski',
#      'firstName': 'Sebastian',
#      'lastName': 'Szymanski',
#      'fullName': 'Sebastian Szymanski',
#      'playerId': 765466,
#      'newScore': [0, 1],
#      'penShootoutScore': None,
#      'shotmapEvent': {'id': 2603683539,
#       'eventType': 'Goal',
#       'teamId': 8568,
#       'playerId': 765466,
#       'playerName': 'Sebastian Szymanski',
#       'x': 86.352941176,
#       'y': 33.084999999999994,
#       'min': 4,
#       'minAdded': None,
#       'isBlocked': False,
#       'isOnTarget': True,
#       'blockedX': None,
#       'blockedY': None,
#       'goalCrossedY': 36.97375,
#       'goalCrossedZ': 0.4879999976,
#       'expectedGoals': 0.11487847566604614,
#       'expectedGoalsOnTarget': 0.3029,
#       'shotType': 'LeftFoot',
#       'situation': 'RegularPlay',
#       'period': 'FirstHalf',
#       'isOwnGoal': False,
#       'onGoalShot': {'x': 0.21329365079365015,
#        'y': 0.12910052846560846,
#        'zoomRatio': 1},
#       'isSavedOffLine': False,
#       'firstName': 'Sebastian',
#       'lastName': 'Szymanski',
#       'fullName': 'Sebastian Szymanski',
#       'teamColor': '#ff2600'},
#      'assistStr': 'assist by Piotr Zielinski',
#      'assistProfileUrl': '/players/362212/piotr-zielinski',
#      'assistPlayerId': 362212,
#      'assistKey': 'assist_by',
#      'assistInput': 'Piotr Zielinski'},
#     {'reactKey': '17Card729731undefinedfalse',
#      'timeStr': 17,
#      'type': 'Card',
#      'time': 17,
#      'overloadTime': None,
#      'eventId': 10645032,
#      'player': {'id': 729731,
#       'name': 'Matty Cash',
#       'profileUrl': '/players/729731/matty-cash'},
#      'profileUrl': '/players/729731/matty-cash',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'nameStr': 'Matty Cash',
#      'card': 'Yellow',
#      'cardDescription': None},
#     {'reactKey': '43Card277460undefinedfalse',
#      'timeStr': 43,
#      'type': 'Card',
#      'time': 43,
#      'overloadTime': None,
#      'eventId': 10645134,
#      'player': {'id': 277460,
#       'name': 'Arkadiusz Milik',
#       'profileUrl': '/players/277460/arkadiusz-milik'},
#      'profileUrl': '/players/277460/arkadiusz-milik',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'nameStr': 'Arkadiusz Milik',
#      'card': 'Yellow',
#      'cardDescription': None},
#     {'reactKey': '45HalfNaNundefinedundefined',
#      'timeStr': 45,
#      'type': 'Half',
#      'time': 45,
#      'overloadTime': None,
#      'player': {'id': None, 'profileUrl': ''},
#      'halfStrShort': 'HT',
#      'halfStrKey': 'halftime_short'},
#     {'reactKey': '49Card495627undefinedtrue',
#      'timeStr': 49,
#      'type': 'Card',
#      'time': 49,
#      'overloadTime': None,
#      'eventId': 10645204,
#      'player': {'id': 495627,
#       'name': 'Hørdur Askham',
#       'profileUrl': '/players/495627/hordur-askham'},
#      'profileUrl': '/players/495627/hordur-askham',
#      'overloadTimeStr': False,
#      'isHome': True,
#      'nameStr': 'Hørdur Askham',
#      'card': 'Red',
#      'cardDescription': None},
#     {'reactKey': '59SubstitutionNaN557396false',
#      'timeStr': 59,
#      'type': 'Substitution',
#      'time': 59,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Adam Buksa',
#        'id': '557396',
#        'profileUrl': '/players/557396/adam-buksa'},
#       {'name': 'Arkadiusz Milik',
#        'id': '277460',
#        'profileUrl': '/players/277460/arkadiusz-milik'}]},
#     {'reactKey': '59SubstitutionNaN558136false',
#      'timeStr': 59,
#      'type': 'Substitution',
#      'time': 59,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Karol Swiderski',
#        'id': '558136',
#        'profileUrl': '/players/558136/karol-swiderski'},
#       {'name': 'Sebastian Szymanski',
#        'id': '765466',
#        'profileUrl': '/players/765466/sebastian-szymanski'}]},
#     {'reactKey': '59SubstitutionNaN206695false',
#      'timeStr': 59,
#      'type': 'Substitution',
#      'time': 59,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Pawel Wszolek',
#        'id': '206695',
#        'profileUrl': '/players/206695/pawel-wszolek'},
#       {'name': 'Matty Cash',
#        'id': '729731',
#        'profileUrl': '/players/729731/matty-cash'}]},
#     {'reactKey': '65Goal557396undefinedfalse',
#      'timeStr': 65,
#      'type': 'Goal',
#      'time': 65,
#      'overloadTime': None,
#      'eventId': 10645312,
#      'player': {'id': 557396,
#       'name': 'Adam Buksa',
#       'profileUrl': '/players/557396/adam-buksa'},
#      'profileUrl': '/players/557396/adam-buksa',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'ownGoal': None,
#      'goalDescription': None,
#      'goalDescriptionKey': None,
#      'suffix': None,
#      'suffixKey': None,
#      'isPenaltyShootoutEvent': False,
#      'nameStr': 'Adam Buksa',
#      'firstName': 'Adam',
#      'lastName': 'Buksa',
#      'fullName': 'Adam Buksa',
#      'playerId': 557396,
#      'newScore': [0, 2],
#      'penShootoutScore': None,
#      'shotmapEvent': {'id': 2603708943,
#       'eventType': 'Goal',
#       'teamId': 8568,
#       'playerId': 557396,
#       'playerName': 'Adam Buksa',
#       'x': 100.1637931038,
#       'y': 36.440000000000005,
#       'min': 65,
#       'minAdded': None,
#       'isBlocked': False,
#       'isOnTarget': True,
#       'blockedX': None,
#       'blockedY': None,
#       'goalCrossedY': 36.135000000000005,
#       'goalCrossedZ': 0.2439999988,
#       'expectedGoals': 0.3510149121284485,
#       'expectedGoalsOnTarget': 0.7853,
#       'shotType': 'Header',
#       'situation': 'RegularPlay',
#       'period': 'SecondHalf',
#       'isOwnGoal': False,
#       'onGoalShot': {'x': 0.4351851851851839,
#        'y': 0.06455026423280423,
#        'zoomRatio': 1},
#       'isSavedOffLine': False,
#       'firstName': 'Adam',
#       'lastName': 'Buksa',
#       'fullName': 'Adam Buksa',
#       'teamColor': '#ff2600'},
#      'assistStr': 'assist by Przemyslaw Frankowski',
#      'assistProfileUrl': '/players/402419/przemyslaw-frankowski',
#      'assistPlayerId': 402419,
#      'assistKey': 'assist_by',
#      'assistInput': 'Przemyslaw Frankowski'},
#     {'reactKey': '76SubstitutionNaN435781true',
#      'timeStr': 76,
#      'type': 'Substitution',
#      'time': 76,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': True,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Ari Mohr Jonsson',
#        'id': '435781',
#        'profileUrl': '/players/435781/ari-mohr-jonsson'},
#       {'name': 'Brandur Hendriksson',
#        'id': '568993',
#        'profileUrl': '/players/568993/brandur-hendriksson'}]},
#     {'reactKey': '76SubstitutionNaN652271true',
#      'timeStr': 76,
#      'type': 'Substitution',
#      'time': 76,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': True,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Pætur Petersen',
#        'id': '652271',
#        'profileUrl': '/players/652271/paetur-petersen'},
#       {'name': 'Joan Simun Edmundsson',
#        'id': '180660',
#        'profileUrl': '/players/180660/joan-simun-edmundsson'}]},
#     {'reactKey': '76SubstitutionNaN946650true',
#      'timeStr': 76,
#      'type': 'Substitution',
#      'time': 76,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': True,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Andrass Johansen',
#        'id': '946650',
#        'profileUrl': '/players/946650/andrass-johansen'},
#       {'name': 'Joannes Bjartalid',
#        'id': '833474',
#        'profileUrl': '/players/833474/joannes-bjartalid'}]},
#     {'reactKey': '82SubstitutionNaN857959true',
#      'timeStr': 82,
#      'type': 'Substitution',
#      'time': 82,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': True,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Joannes Kalsø Danielsen',
#        'id': '857959',
#        'profileUrl': '/players/857959/joannes-kalso-danielsen'},
#       {'name': 'Jakup Andreasen',
#        'id': '857954',
#        'profileUrl': '/players/857954/jakup-andreasen'}]},
#     {'reactKey': '82SubstitutionNaN689987false',
#      'timeStr': 82,
#      'type': 'Substitution',
#      'time': 82,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Jakub Piotrowski',
#        'id': '689987',
#        'profileUrl': '/players/689987/jakub-piotrowski'},
#       {'name': 'Patryk Dziczek',
#        'id': '558189',
#        'profileUrl': '/players/558189/patryk-dziczek'}]},
#     {'reactKey': '86Card435781undefinedtrue',
#      'timeStr': 86,
#      'type': 'Card',
#      'time': 86,
#      'overloadTime': None,
#      'eventId': 10645460,
#      'player': {'id': 435781,
#       'name': 'Ari Mohr Jonsson',
#       'profileUrl': '/players/435781/ari-mohr-jonsson'},
#      'profileUrl': '/players/435781/ari-mohr-jonsson',
#      'overloadTimeStr': False,
#      'isHome': True,
#      'nameStr': 'Ari Mohr Jonsson',
#      'card': 'Yellow',
#      'cardDescription': None},
#     {'reactKey': '87SubstitutionNaN1003329false',
#      'timeStr': 87,
#      'type': 'Substitution',
#      'time': 87,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': False,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Filip Marchwinski',
#        'id': '1003329',
#        'profileUrl': '/players/1003329/filip-marchwinski'},
#       {'name': 'Piotr Zielinski',
#        'id': '362212',
#        'profileUrl': '/players/362212/piotr-zielinski'}]},
#     {'reactKey': '90SubstitutionNaN1059387true',
#      'timeStr': 90,
#      'type': 'Substitution',
#      'time': 90,
#      'overloadTime': 0,
#      'player': {'id': None, 'profileUrl': ''},
#      'profileUrl': '',
#      'overloadTimeStr': False,
#      'isHome': True,
#      'injuredPlayerOut': False,
#      'swap': [{'name': 'Stefan Radosavljevic',
#        'id': '1059387',
#        'profileUrl': '/players/1059387/stefan-radosavljevic'},
#       {'name': 'Sølvi Vatnhamar',
#        'id': '207984',
#        'profileUrl': '/players/207984/solvi-vatnhamar'}]},
#     {'reactKey': '90Card689987undefinedfalse',
#      'timeStr': '90 + 3',
#      'type': 'Card',
#      'time': 90,
#      'overloadTime': 3,
#      'eventId': 10645507,
#      'player': {'id': 689987,
#       'name': 'Jakub Piotrowski',
#       'profileUrl': '/players/689987/jakub-piotrowski'},
#      'profileUrl': '/players/689987/jakub-piotrowski',
#      'overloadTimeStr': '+3',
#      'isHome': False,
#      'nameStr': 'Jakub Piotrowski',
#      'card': 'Yellow',
#      'cardDescription': None},
#     {'reactKey': '90Card138124undefinedtrue',
#      'timeStr': '90 + 4',
#      'type': 'Card',
#      'time': 90,
#      'overloadTime': 4,
#      'eventId': 10645509,
#      'player': {'id': 138124,
#       'name': 'Odmar Færø',
#       'profileUrl': '/players/138124/odmar-faero'},
#      'profileUrl': '/players/138124/odmar-faero',
#      'overloadTimeStr': '+4',
#      'isHome': True,
#      'nameStr': 'Odmar Færø',
#      'card': 'Yellow',
#      'cardDescription': None},
#     {'reactKey': '90Card742332undefinedfalse',
#      'timeStr': '90 + 5',
#      'type': 'Card',
#      'time': 90,
#      'overloadTime': 5,
#      'eventId': 10645511,
#      'player': {'id': 742332,
#       'name': 'Bartosz Slisz',
#       'profileUrl': '/players/742332/bartosz-slisz'},
#      'profileUrl': '/players/742332/bartosz-slisz',
#      'overloadTimeStr': '+5',
#      'isHome': False,
#      'nameStr': 'Bartosz Slisz',
#      'card': 'Yellow',
#      'cardDescription': None},
#     {'reactKey': '90HalfNaNundefinedundefined',
#      'timeStr': 90,
#      'type': 'Half',
#      'time': 90,
#      'overloadTime': None,
#      'player': {'id': None, 'profileUrl': ''},
#      'halfStrShort': 'FT',
#      'halfStrKey': 'fulltime_short'}],
#    'eventTypes': ['Goal',
#     'Assist',
#     'Card',
#     'Half',
#     'Substitution',
#     None,
#     None,
#     'Yellow',
#     'Red',
#     [],
#     []],
#    'penaltyShootoutEvents': None},
#   'infoBox': {'Match Date': {'utcTime': '2023-10-12T18:45:00.000Z'},
#    'Tournament': {'id': 881526,
#     'parentLeagueId': 50,
#     'link': '/leagues/50/overview/euro-qualification-grp-e?season=2023',
#     'leagueName': 'EURO Qualification Grp. E',
#     'roundName': 'Round 7',
#     'round': '7',
#     'selectedSeason': '2023',
#     'isCurrentSeason': True},
#    'Stadium': {'name': 'Tórsvøllur',
#     'city': 'Tórshavn, Streymoy',
#     'country': 'Faroe Islands',
#     'lat': 62.019198,
#     'long': -6.777948},
#    'Referee': {'imgUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/ned.png',
#     'text': 'Allard Lindhout',
#     'country': 'Netherlands'}},
#   'teamForm': [[{'result': -1,
#      'resultString': 'L',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8260_xsmall.png',
#      'linkToMatch': '/match/4113788/matchfacts/north-macedonia-vs-faroe-islands',
#      'date': {'utcTime': '2023-03-27T16:00:00.000Z'},
#      'teamPageUrl': '/teams/8260/overview/north-macedonia',
#      'tooltipText': {'utcTime': '2023-03-27T16:00:00.000Z',
#       'homeTeam': 'North Macedonia',
#       'homeTeamId': 8260,
#       'homeScore': '1',
#       'awayTeam': 'Faroe Islands',
#       'awayTeamId': 8269,
#       'awayScore': '0'},
#      'score': '1 - 0',
#      'home': {'id': '8260', 'name': 'North Macedonia', 'isOurTeam': False},
#      'away': {'id': '8269', 'name': 'Faroe Islands', 'isOurTeam': True}},
#     {'result': -1,
#      'resultString': 'L',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8496_xsmall.png',
#      'linkToMatch': '/match/4044723/matchfacts/faroe-islands-vs-czechia',
#      'date': {'utcTime': '2023-06-17T18:45:00.000Z'},
#      'teamPageUrl': '/teams/8496/overview/czechia',
#      'tooltipText': {'utcTime': '2023-06-17T18:45:00.000Z',
#       'homeTeam': 'Faroe Islands',
#       'homeTeamId': 8269,
#       'homeScore': '0',
#       'awayTeam': 'Czechia',
#       'awayTeamId': 8496,
#       'awayScore': '3'},
#      'score': '0 - 3',
#      'home': {'id': '8269', 'name': 'Faroe Islands', 'isOurTeam': True},
#      'away': {'id': '8496', 'name': 'Czechia', 'isOurTeam': False}},
#     {'result': -1,
#      'resultString': 'L',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/10024_xsmall.png',
#      'linkToMatch': '/match/4044725/matchfacts/faroe-islands-vs-albania',
#      'date': {'utcTime': '2023-06-20T18:45:00.000Z'},
#      'teamPageUrl': '/teams/10024/overview/albania',
#      'tooltipText': {'utcTime': '2023-06-20T18:45:00.000Z',
#       'homeTeam': 'Faroe Islands',
#       'homeTeamId': 8269,
#       'homeScore': '1',
#       'awayTeam': 'Albania',
#       'awayTeamId': 10024,
#       'awayScore': '3'},
#      'score': '1 - 3',
#      'home': {'id': '8269', 'name': 'Faroe Islands', 'isOurTeam': True},
#      'away': {'id': '10024', 'name': 'Albania', 'isOurTeam': False}},
#     {'result': -1,
#      'resultString': 'L',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8568_xsmall.png',
#      'linkToMatch': '/match/4044726/matchfacts/poland-vs-faroe-islands',
#      'date': {'utcTime': '2023-09-07T18:45:00.000Z'},
#      'teamPageUrl': '/teams/8568/overview/poland',
#      'tooltipText': {'utcTime': '2023-09-07T18:45:00.000Z',
#       'homeTeam': 'Poland',
#       'homeTeamId': 8568,
#       'homeScore': '2',
#       'awayTeam': 'Faroe Islands',
#       'awayTeamId': 8269,
#       'awayScore': '0'},
#      'score': '2 - 0',
#      'home': {'id': '8568', 'name': 'Poland', 'isOurTeam': False},
#      'away': {'id': '8269', 'name': 'Faroe Islands', 'isOurTeam': True}},
#     {'result': -1,
#      'resultString': 'L',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/5794_xsmall.png',
#      'linkToMatch': '/match/4044728/matchfacts/faroe-islands-vs-moldova',
#      'date': {'utcTime': '2023-09-10T16:00:00.000Z'},
#      'teamPageUrl': '/teams/5794/overview/moldova',
#      'tooltipText': {'utcTime': '2023-09-10T16:00:00.000Z',
#       'homeTeam': 'Faroe Islands',
#       'homeTeamId': 8269,
#       'homeScore': '0',
#       'awayTeam': 'Moldova',
#       'awayTeamId': 5794,
#       'awayScore': '1'},
#      'score': '0 - 1',
#      'home': {'id': '8269', 'name': 'Faroe Islands', 'isOurTeam': True},
#      'away': {'id': '5794', 'name': 'Moldova', 'isOurTeam': False}}],
#    [{'result': 1,
#      'resultString': 'W',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/10024_xsmall.png',
#      'linkToMatch': '/match/4044720/matchfacts/poland-vs-albania',
#      'date': {'utcTime': '2023-03-27T18:45:00.000Z'},
#      'teamPageUrl': '/teams/10024/overview/albania',
#      'tooltipText': {'utcTime': '2023-03-27T18:45:00.000Z',
#       'homeTeam': 'Poland',
#       'homeTeamId': 8568,
#       'homeScore': '1',
#       'awayTeam': 'Albania',
#       'awayTeamId': 10024,
#       'awayScore': '0'},
#      'score': '1 - 0',
#      'home': {'id': '8568', 'name': 'Poland', 'isOurTeam': True},
#      'away': {'id': '10024', 'name': 'Albania', 'isOurTeam': False}},
#     {'result': 1,
#      'resultString': 'W',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8570_xsmall.png',
#      'linkToMatch': '/match/4162620/matchfacts/poland-vs-germany',
#      'date': {'utcTime': '2023-06-16T18:45:00.000Z'},
#      'teamPageUrl': '/teams/8570/overview/germany',
#      'tooltipText': {'utcTime': '2023-06-16T18:45:00.000Z',
#       'homeTeam': 'Poland',
#       'homeTeamId': 8568,
#       'homeScore': '1',
#       'awayTeam': 'Germany',
#       'awayTeamId': 8570,
#       'awayScore': '0'},
#      'score': '1 - 0',
#      'home': {'id': '8568', 'name': 'Poland', 'isOurTeam': True},
#      'away': {'id': '8570', 'name': 'Germany', 'isOurTeam': False}},
#     {'result': -1,
#      'resultString': 'L',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/5794_xsmall.png',
#      'linkToMatch': '/match/4044724/matchfacts/moldova-vs-poland',
#      'date': {'utcTime': '2023-06-20T18:45:00.000Z'},
#      'teamPageUrl': '/teams/5794/overview/moldova',
#      'tooltipText': {'utcTime': '2023-06-20T18:45:00.000Z',
#       'homeTeam': 'Moldova',
#       'homeTeamId': 5794,
#       'homeScore': '3',
#       'awayTeam': 'Poland',
#       'awayTeamId': 8568,
#       'awayScore': '2'},
#      'score': '3 - 2',
#      'home': {'id': '5794', 'name': 'Moldova', 'isOurTeam': False},
#      'away': {'id': '8568', 'name': 'Poland', 'isOurTeam': True}},
#     {'result': 1,
#      'resultString': 'W',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8269_xsmall.png',
#      'linkToMatch': '/match/4044726/matchfacts/poland-vs-faroe-islands',
#      'date': {'utcTime': '2023-09-07T18:45:00.000Z'},
#      'teamPageUrl': '/teams/8269/overview/faroe-islands',
#      'tooltipText': {'utcTime': '2023-09-07T18:45:00.000Z',
#       'homeTeam': 'Poland',
#       'homeTeamId': 8568,
#       'homeScore': '2',
#       'awayTeam': 'Faroe Islands',
#       'awayTeamId': 8269,
#       'awayScore': '0'},
#      'score': '2 - 0',
#      'home': {'id': '8568', 'name': 'Poland', 'isOurTeam': True},
#      'away': {'id': '8269', 'name': 'Faroe Islands', 'isOurTeam': False}},
#     {'result': -1,
#      'resultString': 'L',
#      'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/10024_xsmall.png',
#      'linkToMatch': '/match/4044729/matchfacts/albania-vs-poland',
#      'date': {'utcTime': '2023-09-10T18:45:00.000Z'},
#      'teamPageUrl': '/teams/10024/overview/albania',
#      'tooltipText': {'utcTime': '2023-09-10T18:45:00.000Z',
#       'homeTeam': 'Albania',
#       'homeTeamId': 10024,
#       'homeScore': '2',
#       'awayTeam': 'Poland',
#       'awayTeamId': 8568,
#       'awayScore': '0'},
#      'score': '2 - 0',
#      'home': {'id': '10024', 'name': 'Albania', 'isOurTeam': False},
#      'away': {'id': '8568', 'name': 'Poland', 'isOurTeam': True}}]],
#   'poll': {'oddspoll': {'PollName': 'oddspoll-match-4044731',
#     'MatchId': 4044731,
#     'HomeTeamId': 8269,
#     'AwayTeamId': 8568,
#     'HomeTeam': 'Faroe Islands',
#     'AwayTeam': 'Poland',
#     'Facts': [{'OddsType': '1x2',
#       'DefaultLabel': 'Who will win?',
#       'TextLabelId': 'who_will_win',
#       'DefaultTemplate': '{0} have lost their last {1} matches.',
#       'TextTemplateId': 'bad_form_team',
#       'StatValues': ['home_team', '5'],
#       'DefaultLabels': ['1', 'x', '2'],
#       'LabelTemplates': ['label_1', 'label_x', 'label_2'],
#       'Icon': 'poll_stat_down',
#       'defaultText': 'Faroe Islands have lost their last 5 matches.'},
#      {'OddsType': 'bts',
#       'DefaultLabel': 'Will both teams score?',
#       'TextLabelId': 'both_score',
#       'DefaultTemplate': '{0} have an average of {2} goals in their last three matches and {1} have an average of {3}.',
#       'TextTemplateId': 'average_goals_last3_both',
#       'StatValues': ['home_team', 'away_team', '0.33', '1.33'],
#       'DefaultLabels': ['yes', 'no'],
#       'LabelTemplates': ['label_yes', 'label_no'],
#       'Icon': 'poll_goal',
#       'defaultText': 'Faroe Islands have an average of 0.33 goals in their last three matches and Poland have an average of 1.33.'},
#      {'OddsType': 'ou',
#       'DefaultLabel': 'Will there be more than 2.5 goals?',
#       'TextLabelId': 'over_under',
#       'DefaultTemplate': '{0} have an average of {2} goals in their last three matches and {1} have an average of {3}.',
#       'TextTemplateId': 'average_goals_last3_both',
#       'StatValues': ['home_team', 'away_team', '0.33', '1.33'],
#       'DefaultLabels': ['yes', 'no'],
#       'LabelTemplates': ['label_yes', 'label_no'],
#       'Icon': 'poll_goal',
#       'defaultText': 'Faroe Islands have an average of 0.33 goals in their last three matches and Poland have an average of 1.33.'},
#      {'OddsType': 'dc',
#       'DefaultLabel': 'Double chance',
#       'TextLabelId': 'double_chance',
#       'DefaultTemplate': "{0} haven't won a match in {1} attempts.",
#       'TextTemplateId': 'not_won_team',
#       'StatValues': ['home_team', '8'],
#       'DefaultLabels': ['1x', '12', 'x2'],
#       'LabelTemplates': ['label_1x', 'label_12', 'label_x2'],
#       'Icon': 'poll_stat_down',
#       'defaultText': "Faroe Islands haven't won a match in 8 attempts."}]},
#    'voteResult': {'PollName': 'oddspoll-match-4044731',
#     'Votes': [{'Name': '1x2', 'Votes': [3273, 4587, 14770]},
#      {'Name': 'bts', 'Votes': [1303, 1280]},
#      {'Name': 'ou', 'Votes': [1698, 723]},
#      {'Name': 'dc', 'Votes': [476, 262, 1091]}]},
#    'renderToTop': False},
#   'topPlayers': {'homeTopPlayers': [{'playerId': 315230,
#      'name': {'firstName': 'René',
#       'lastName': 'Joensen',
#       'fullName': 'René Joensen'},
#      'playerRatingRounded': '7.1',
#      'color': '#1ec853',
#      'manOfTheMatch': False,
#      'teamId': '8269',
#      'positionLabel': {'label': 'LW', 'key': 'leftwinger_short'}},
#     {'playerId': 946650,
#      'name': {'firstName': 'Andrass',
#       'lastName': 'Johansen',
#       'fullName': 'Andrass Johansen'},
#      'playerRatingRounded': '6.8',
#      'color': '#f08022',
#      'manOfTheMatch': False,
#      'teamId': '8269',
#      'positionLabel': None},
#     {'playerId': 568993,
#      'name': {'firstName': 'Brandur',
#       'lastName': 'Hendriksson',
#       'fullName': 'Brandur Hendriksson'},
#      'playerRatingRounded': '6.4',
#      'color': '#f08022',
#      'manOfTheMatch': False,
#      'teamId': '8269',
#      'positionLabel': {'label': 'DM',
#       'key': 'centerdefensivemidfielder_short'}}],
#    'awayTopPlayers': [{'playerId': 402419,
#      'name': {'firstName': 'Przemyslaw',
#       'lastName': 'Frankowski',
#       'fullName': 'Przemyslaw Frankowski'},
#      'playerRatingRounded': '8.5',
#      'color': '#1ec853',
#      'manOfTheMatch': True,
#      'teamId': '8568',
#      'positionLabel': {'label': 'LM', 'key': 'leftmidfielder_short'}},
#     {'playerId': 765466,
#      'name': {'firstName': 'Sebastian',
#       'lastName': 'Szymanski',
#       'fullName': 'Sebastian Szymanski'},
#      'playerRatingRounded': '8.1',
#      'color': '#1ec853',
#      'manOfTheMatch': False,
#      'teamId': '8568',
#      'positionLabel': {'label': 'RW', 'key': 'rightwinger_short'}},
#     {'playerId': 362212,
#      'name': {'firstName': 'Piotr',
#       'lastName': 'Zielinski',
#       'fullName': 'Piotr Zielinski'},
#      'playerRatingRounded': '7.8',
#      'color': '#1ec853',
#      'manOfTheMatch': False,
#      'teamId': '8568',
#      'positionLabel': {'label': 'LW', 'key': 'leftwinger_short'}}]},
#   'insights': [{'type': 'team',
#     'playerId': None,
#     'teamId': 8269,
#     'priority': 1344,
#     'defaultText': 'Have lost their last {0} matches',
#     'localizedTextId': 'insights_bad_form_team',
#     'statValues': [{'value': 5, 'name': None, 'type': 'integer'}],
#     'text': 'Have lost their last 5 matches',
#     'color': '#3060A8'},
#    {'type': 'team',
#     'playerId': None,
#     'teamId': 8568,
#     'priority': 1344,
#     'defaultText': "Haven't won an away game in their last {0} matches",
#     'localizedTextId': 'insights_not_won_away',
#     'statValues': [{'value': 5, 'name': None, 'type': 'integer'}],
#     'text': "Haven't won an away game in their last 5 matches",
#     'color': '#ff2600'}],
#   'momentum': {'main': {'data': [{'minute': 1, 'value': 5},
#      {'minute': 2, 'value': 5},
#      {'minute': 3, 'value': 5},
#      {'minute': 4, 'value': -16},
#      {'minute': 5, 'value': -16},
#      {'minute': 6, 'value': -14},
#      {'minute': 7, 'value': -14},
#      {'minute': 8, 'value': -19},
#      {'minute': 9, 'value': -22},
#      {'minute': 10, 'value': 5},
#      {'minute': 11, 'value': 16},
#      {'minute': 12, 'value': 19},
#      {'minute': 13, 'value': 35},
#      {'minute': 14, 'value': 46},
#      {'minute': 15, 'value': 11},
#      {'minute': 16, 'value': -14},
#      {'minute': 17, 'value': -30},
#      {'minute': 18, 'value': -14},
#      {'minute': 19, 'value': -16},
#      {'minute': 20, 'value': -19},
#      {'minute': 21, 'value': 24},
#      {'minute': 22, 'value': 8},
#      {'minute': 23, 'value': 11},
#      {'minute': 24, 'value': -11},
#      {'minute': 25, 'value': 0},
#      {'minute': 26, 'value': 0},
#      {'minute': 27, 'value': -5},
#      {'minute': 28, 'value': 60},
#      {'minute': 29, 'value': -11},
#      {'minute': 30, 'value': -11},
#      {'minute': 31, 'value': -71},
#      {'minute': 32, 'value': -11},
#      {'minute': 33, 'value': -43},
#      {'minute': 34, 'value': -38},
#      {'minute': 35, 'value': -27},
#      {'minute': 36, 'value': 5},
#      {'minute': 37, 'value': 0},
#      {'minute': 38, 'value': -16},
#      {'minute': 39, 'value': -90},
#      {'minute': 40, 'value': -84},
#      {'minute': 41, 'value': -46},
#      {'minute': 42, 'value': 33},
#      {'minute': 43, 'value': 27},
#      {'minute': 44, 'value': 5},
#      {'minute': 45, 'value': -16},
#      {'minute': 45.5, 'value': -14},
#      {'minute': 46, 'value': -16},
#      {'minute': 47, 'value': -16},
#      {'minute': 48, 'value': -16},
#      {'minute': 49, 'value': 0},
#      {'minute': 50, 'value': 0},
#      {'minute': 51, 'value': 5},
#      {'minute': 52, 'value': -11},
#      {'minute': 53, 'value': -16},
#      {'minute': 54, 'value': -100},
#      {'minute': 55, 'value': -100},
#      {'minute': 56, 'value': -100},
#      {'minute': 57, 'value': -24},
#      {'minute': 58, 'value': -41},
#      {'minute': 59, 'value': -5},
#      {'minute': 60, 'value': -33},
#      {'minute': 61, 'value': -22},
#      {'minute': 62, 'value': -16},
#      {'minute': 63, 'value': -5},
#      {'minute': 64, 'value': -81},
#      {'minute': 65, 'value': -100},
#      {'minute': 66, 'value': -100},
#      {'minute': 67, 'value': -100},
#      {'minute': 68, 'value': -3},
#      {'minute': 69, 'value': -14},
#      {'minute': 70, 'value': 19},
#      {'minute': 71, 'value': -41},
#      {'minute': 72, 'value': -52},
#      {'minute': 73, 'value': -60},
#      {'minute': 74, 'value': -43},
#      {'minute': 75, 'value': -16},
#      {'minute': 76, 'value': -11},
#      {'minute': 77, 'value': -11},
#      {'minute': 78, 'value': -27},
#      {'minute': 79, 'value': -52},
#      {'minute': 80, 'value': -57},
#      {'minute': 81, 'value': -57},
#      {'minute': 82, 'value': -33},
#      {'minute': 83, 'value': -11},
#      {'minute': 84, 'value': -11},
#      {'minute': 85, 'value': -16},
#      {'minute': 86, 'value': -38},
#      {'minute': 87, 'value': -27},
#      {'minute': 88, 'value': -41},
#      {'minute': 89, 'value': -19},
#      {'minute': 90, 'value': -24},
#      {'minute': 90.5, 'value': 6}],
#     'debugTitle': 'Using xT SA-version'},
#    'alternateModels': []},
#   'countryCode': 'INT',
#   'QAData': [{'question': 'Who won between Faroe Islands and Poland on Thu, 12 Oct 2023 18:45:00 GMT?',
#     'answer': 'Poland won 2–0 over Faroe Islands on Thu, 12 Oct 2023 18:45:00 GMT.'}]},
#  {'langs': 'de_gen,en_gen,es_gen,fr_gen,it_gen',
#   'teams': ['Faroe Islands', 'Poland'],
#   'superLiveUrl': 'https://pub.fotmob.com/prod/news/api/law?matchid=9w6iptcda49ted2wqbcpy6uj8&competition=gfskxsdituog2kqp9yiu7bzi&season=ol0rl83a8kdhznchbutsjlzo&version=v4a',
#   'showSuperLive': False},
#  None,
#  {'Periods': {'All': {'stats': [{'title': 'Top stats',
#       'key': 'top_stats',
#       'stats': [{'title': 'Ball possession',
#         'key': 'BallPossesion',
#         'stats': [34, 66],
#         'type': 'graph',
#         'highlighted': 'away'},
#        {'title': 'Expected goals (xG)',
#         'key': 'expected_goals',
#         'stats': ['0.05', '1.52'],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Total shots',
#         'key': 'total_shots',
#         'stats': [2, 13],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Shots on target',
#         'key': 'ShotsOnTarget',
#         'stats': [0, 4],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Big chances',
#         'key': 'big_chance',
#         'stats': [0, 2],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Big chances missed',
#         'key': 'big_chance_missed_title',
#         'stats': [0, 1],
#         'type': 'text',
#         'highlighted': 'home'},
#        {'title': 'Accurate passes',
#         'key': 'accurate_passes',
#         'stats': ['241 (74%)', '553 (87%)'],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Fouls committed',
#         'key': 'fouls',
#         'stats': [13, 10],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Corners',
#         'key': 'corners',
#         'stats': [4, 3],
#         'type': 'text',
#         'highlighted': 'home'}]},
#      {'title': 'Shots',
#       'key': 'shots',
#       'stats': [{'title': 'Shots',
#         'key': 'shots',
#         'stats': [None, None],
#         'type': 'title',
#         'highlighted': 'equal'},
#        {'title': 'Total shots',
#         'key': 'total_shots',
#         'stats': [2, 13],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Shots off target',
#         'key': 'ShotsOffTarget',
#         'stats': [2, 4],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Shots on target',
#         'key': 'ShotsOnTarget',
#         'stats': [0, 4],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Blocked shots',
#         'key': 'blocked_shots',
#         'stats': [0, 5],
#         'type': 'text',
#         'highlighted': 'away'},
#        {'title': 'Hit woodwork',
#         'key': 'shots_woodwork',
#         'stats': [0, 0],
#         'type': 'text',
#         'highlighted': 'equal'},
#        {'title': 'Shots inside box',
# ...
#       'position': 'Substitute',
#       'localizedPosition': None,
#       'name': {'firstName': 'Filip',
#        'lastName': 'Marchwinski',
#        'fullName': 'Filip Marchwinski'},
#       'shirt': 8,
#       'usualPosition': 2,
#       'usingOptaId': False,
#       'teamId': '8568',
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/1003329.png',
#       'pageUrl': '/players/1003329/filip-marchwinski',
#       'isHomeTeam': False,
#       'timeSubbedOn': 87,
#       'timeSubbedOff': None,
#       'positionRow': 0,
#       'role': 'Midfielder',
#       'events': {'sub': {'subbedIn': 87}},
#       'rating': {'num': None,
#        'bgcolor': '#989898',
#        'isTop': {'isTopRating': False, 'isMatchFinished': True}},
#       'fantasyScore': {'num': None, 'bgcolor': 'purple'},
#       'minutesPlayed': 3,
#       'shotmap': [{'id': 2603719329,
#         'eventType': 'Miss',
#         'teamId': 8568,
#         'playerId': 1003329,
#         'playerName': 'Filip Marchwinski',
#         'x': 100.1637931038,
#         'y': 45.3319745182,
#         'min': 88,
#         'minAdded': None,
#         'isBlocked': False,
#         'isOnTarget': False,
#         'blockedX': None,
#         'blockedY': None,
#         'goalCrossedY': 39.460952381999995,
#         'goalCrossedZ': 0.802631575,
#         'expectedGoals': 0.07512927800416946,
#         'expectedGoalsOnTarget': None,
#         'shotType': 'LeftFoot',
#         'situation': 'RegularPlay',
#         'period': 'SecondHalf',
#         'isOwnGoal': False,
#         'onGoalShot': {'x': 0,
#          'y': 0.14697648301156727,
#          'zoomRatio': 0.6921869548724447},
#         'isSavedOffLine': False,
#         'teamColor': '#ff2600'}],
#       'stats': [{'title': 'Top stats',
#         'key': 'top_stats',
#         'stats': {'FotMob rating': {'key': 'rating_title', 'value': 0},
#          'Minutes played': {'key': 'minutes_played', 'value': 3},
#          'Goals': {'key': 'goals', 'value': 0},
#          'Assists': {'key': 'assists', 'value': 0},
#          'Total shots': {'key': 'total_shots', 'value': 1},
#          'Shotmap': {'key': None, 'value': True},
#          'Accurate passes': {'key': 'accurate_passes', 'value': '1/1 (100%)'},
#          'Chances created': {'key': 'chances_created', 'value': 0},
#          'Expected goals (xG)': {'key': 'expected_goals', 'value': '0.08'},
#          'xG + xA': {'key': 'xg_and_xa', 'value': '0.08'}}},
#        {'title': 'Attack',
#         'key': 'attack',
#         'stats': {'Shot accuracy': {'key': 'shot_accuracy',
#           'value': '0/1 (0%)'},
#          'Touches': {'key': 'touches', 'value': 3},
#          'Dispossessed': {'key': 'dispossessed', 'value': 0},
#          'xG Non-penalty': {'key': 'expected_goals_non_penalty',
#           'value': '0.08'}}},
#        {'title': 'Defense',
#         'key': 'defense',
#         'stats': {'Tackles won': {'key': 'tackles_succeeded', 'value': 0},
#          'Clearances': {'key': 'clearances', 'value': 1},
#          'Headed clearance': {'key': 'headed_clearance', 'value': 1},
#          'Defensive actions': {'key': 'defensive_actions', 'value': 1}}},
#        {'title': 'Duels',
#         'key': 'duels',
#         'stats': {'Ground duels won': {'key': 'ground_duels_won', 'value': 0},
#          'Aerial duels won': {'key': 'aerials_won', 'value': 0},
#          'Was fouled': {'key': 'was_fouled', 'value': 0},
#          'Fouls committed': {'key': 'fouls', 'value': 0}}}],
#       'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#        'away': {'id': 8269, 'color': '#ff2600'}},
#       'isGoalkeeper': False},
#      {'id': '1067260',
#       'positionId': 0,
#       'position': 'Substitute',
#       'localizedPosition': None,
#       'name': {'firstName': 'Jakub',
#        'lastName': 'Kaminski',
#        'fullName': 'Jakub Kaminski'},
#       'shirt': 13,
#       'usualPosition': 3,
#       'usingOptaId': False,
#       'teamId': '8568',
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/1067260.png',
#       'pageUrl': '/players/1067260/jakub-kaminski',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': 0,
#       'role': 'Attacker',
#       'events': {},
#       'rating': {'num': None,
#        'bgcolor': '#989898',
#        'isTop': {'isTopRating': False, 'isMatchFinished': True}},
#       'fantasyScore': {'num': None, 'bgcolor': 'purple'},
#       'minutesPlayed': 0,
#       'shotmap': [],
#       'stats': [],
#       'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#        'away': {'id': 8269, 'color': '#ff2600'}},
#       'isGoalkeeper': False},
#      {'id': '69541',
#       'positionId': 0,
#       'position': 'Substitute',
#       'localizedPosition': None,
#       'name': {'firstName': 'Kamil',
#        'lastName': 'Grosicki',
#        'fullName': 'Kamil Grosicki'},
#       'shirt': 11,
#       'usualPosition': 3,
#       'usingOptaId': False,
#       'teamId': '8568',
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/69541.png',
#       'pageUrl': '/players/69541/kamil-grosicki',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': 0,
#       'role': 'Attacker',
#       'events': {},
#       'rating': {'num': None,
#        'bgcolor': '#989898',
#        'isTop': {'isTopRating': False, 'isMatchFinished': True}},
#       'fantasyScore': {'num': None, 'bgcolor': 'purple'},
#       'minutesPlayed': 0,
#       'shotmap': [],
#       'stats': [],
#       'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#        'away': {'id': 8269, 'color': '#ff2600'}},
#       'isGoalkeeper': False},
#      {'id': '465828',
#       'positionId': 0,
#       'position': 'Substitute',
#       'localizedPosition': None,
#       'name': {'firstName': 'Damian',
#        'lastName': 'Szymanski',
#        'fullName': 'Damian Szymanski'},
#       'shirt': 17,
#       'usualPosition': 2,
#       'usingOptaId': False,
#       'teamId': '8568',
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/465828.png',
#       'pageUrl': '/players/465828/damian-szymanski',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': 0,
#       'role': 'Midfielder',
#       'events': {},
#       'rating': {'num': None,
#        'bgcolor': '#989898',
#        'isTop': {'isTopRating': False, 'isMatchFinished': True}},
#       'fantasyScore': {'num': None, 'bgcolor': 'purple'},
#       'minutesPlayed': 0,
#       'shotmap': [],
#       'stats': [],
#       'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#        'away': {'id': 8269, 'color': '#ff2600'}},
#       'isGoalkeeper': False},
#      {'id': '555646',
#       'positionId': 0,
#       'position': 'Substitute',
#       'localizedPosition': None,
#       'name': {'firstName': 'Mateusz',
#        'lastName': 'Wieteska',
#        'fullName': 'Mateusz Wieteska'},
#       'shirt': 3,
#       'usualPosition': 1,
#       'usingOptaId': False,
#       'teamId': '8568',
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/555646.png',
#       'pageUrl': '/players/555646/mateusz-wieteska',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': 0,
#       'role': 'Defender',
#       'events': {},
#       'rating': {'num': None,
#        'bgcolor': '#989898',
#        'isTop': {'isTopRating': False, 'isMatchFinished': True}},
#       'fantasyScore': {'num': None, 'bgcolor': 'purple'},
#       'minutesPlayed': 0,
#       'shotmap': [],
#       'stats': [],
#       'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#        'away': {'id': 8269, 'color': '#ff2600'}},
#       'isGoalkeeper': False},
#      {'id': '860592',
#       'positionId': 0,
#       'position': 'Substitute',
#       'localizedPosition': None,
#       'name': {'firstName': 'Sebastian',
#        'lastName': 'Walukiewicz',
#        'fullName': 'Sebastian Walukiewicz'},
#       'shirt': 15,
#       'usualPosition': 1,
#       'usingOptaId': False,
#       'teamId': '8568',
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/860592.png',
#       'pageUrl': '/players/860592/sebastian-walukiewicz',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': 0,
#       'role': 'Defender',
#       'events': {},
#       'rating': {'num': None,
#        'bgcolor': '#989898',
#        'isTop': {'isTopRating': False, 'isMatchFinished': True}},
#       'fantasyScore': {'num': None, 'bgcolor': 'purple'},
#       'minutesPlayed': 0,
#       'shotmap': [],
#       'stats': [],
#       'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#        'away': {'id': 8269, 'color': '#ff2600'}},
#       'isGoalkeeper': False},
#      {'id': '178732',
#       'positionId': 0,
#       'position': 'Substitute',
#       'localizedPosition': None,
#       'name': {'firstName': 'Lukasz',
#        'lastName': 'Skorupski',
#        'fullName': 'Lukasz Skorupski'},
#       'shirt': 12,
#       'usualPosition': 0,
#       'usingOptaId': False,
#       'teamId': '8568',
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/178732.png',
#       'pageUrl': '/players/178732/lukasz-skorupski',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': 0,
#       'role': 'Keeper',
#       'events': {},
#       'rating': {'num': None,
#        'bgcolor': '#989898',
#        'isTop': {'isTopRating': False, 'isMatchFinished': True}},
#       'fantasyScore': {'num': None, 'bgcolor': 'purple'},
#       'minutesPlayed': 0,
#       'shotmap': [],
#       'stats': [],
#       'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#        'away': {'id': 8269, 'color': '#ff2600'}},
#       'isGoalkeeper': True},
#      {'id': '863455',
#       'positionId': 0,
#       'position': 'Substitute',
#       'localizedPosition': None,
#       'name': {'firstName': 'Marcin',
#        'lastName': 'Bulka',
#        'fullName': 'Marcin Bulka'},
#       'shirt': 22,
#       'usualPosition': 0,
#       'usingOptaId': False,
#       'teamId': '8568',
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/863455.png',
#       'pageUrl': '/players/863455/marcin-bulka',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': 0,
#       'role': 'Keeper',
#       'events': {},
#       'rating': {'num': None,
#        'bgcolor': '#989898',
#        'isTop': {'isTopRating': False, 'isMatchFinished': True}},
#       'fantasyScore': {'num': None, 'bgcolor': 'purple'},
#       'minutesPlayed': 0,
#       'shotmap': [],
#       'stats': [],
#       'teamData': {'home': {'id': 8269, 'color': '#3060A8'},
#        'away': {'id': 8269, 'color': '#ff2600'}},
#       'isGoalkeeper': True}]]},
#   'naPlayers': {'sides': ['home', 'away'], 'naPlayersArr': [[], []]},
#   'coaches': {'sides': ['home', 'away'],
#    'coachesArr': [[{'id': '646618',
#       'name': {'firstName': 'Håkan',
#        'lastName': 'Ericson',
#        'fullName': 'Håkan Ericson'},
#       'usualPosition': 5,
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/646618.png',
#       'pageUrl': '/players/646618/hakan-ericson',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': None,
#       'role': 'Coach',
#       'isCaptain': False,
#       'events': {}}],
#     [{'id': '354991',
#       'name': {'firstName': 'Michal',
#        'lastName': 'Probierz',
#        'fullName': 'Michal Probierz'},
#       'usualPosition': 5,
#       'imageUrl': 'https://images.fotmob.com/image_resources/playerimages/354991.png',
#       'pageUrl': '/players/354991/michal-probierz',
#       'isHomeTeam': False,
#       'timeSubbedOn': None,
#       'timeSubbedOff': None,
#       'positionRow': None,
#       'role': 'Coach',
#       'isCaptain': False,
#       'events': {}}]]},
#   'teamRatings': {'home': {'num': 6.12, 'bgcolor': '#f08022'},
#    'away': {'num': 7.33, 'bgcolor': '#1ec853'}},
#   'hasFantasy': False,
#   'usingEnetpulseLineup': True,
#   'usingOptaLineup': False,
#   'simpleLineup': False},
#  False,
#  {'url': 'https://data.fotmob.com/tables.ext.50.fot',
#   'teams': [8269, 8568],
#   'tournamentNameForUrl': 'EURO Qualification Grp. E',
#   'parentLeagueId': 50,
#   'parentLeagueName': 'EURO',
#   'isCurrentSeason': True,
#   'parentLeagueSeason': '2023',
#   'countryCode': 'INT'},
#  {'summary': [0, 0, 1],
#   'matches': [{'time': {'utcTime': '2023-09-07T18:45:00.000Z'},
#     'matchUrl': '/match/4044726/matchfacts/poland-vs-faroe-islands',
#     'league': {'name': 'EURO Qualification Grp. E',
#      'id': '50',
#      'pageUrl': '/leagues/50/overview/euro-qualification-grp-e'},
#     'home': {'name': 'Poland', 'id': '8568'},
#     'status': {'utcTime': '2023-09-07T18:45:00.000Z',
#      'finished': True,
#      'started': True,
#      'cancelled': False,
#      'scoreStr': '2 - 0',
#      'reason': {'short': 'FT',
#       'shortKey': 'fulltime_short',
#       'long': 'Full-Time',
#       'longKey': 'finished'}},
#     'finished': False,
#     'away': {'name': 'Faroe Islands', 'id': '8269'}}]},
#  {'main': {'data': [{'minute': 0, 'value': 0},
#     {'minute': 1, 'value': 5},
#     {'minute': 2, 'value': 5},
#     {'minute': 3, 'value': 5},
#     {'minute': 4, 'value': -16},
#     {'minute': 5, 'value': -16},
#     {'minute': 6, 'value': -14},
#     {'minute': 7, 'value': -14},
#     {'minute': 8, 'value': -19},
#     {'minute': 9, 'value': -22},
#     {'minute': 10, 'value': 5},
#     {'minute': 11, 'value': 16},
#     {'minute': 12, 'value': 19},
#     {'minute': 13, 'value': 35},
#     {'minute': 14, 'value': 46},
#     {'minute': 15, 'value': 11},
#     {'minute': 16, 'value': -14},
#     {'minute': 17, 'value': -30},
#     {'minute': 18, 'value': -14},
#     {'minute': 19, 'value': -16},
#     {'minute': 20, 'value': -19},
#     {'minute': 21, 'value': 24},
#     {'minute': 22, 'value': 8},
#     {'minute': 23, 'value': 11},
#     {'minute': 24, 'value': -11},
#     {'minute': 25, 'value': 0},
#     {'minute': 26, 'value': 0},
#     {'minute': 27, 'value': -5},
#     {'minute': 28, 'value': 60},
#     {'minute': 29, 'value': -11},
#     {'minute': 30, 'value': -11},
#     {'minute': 31, 'value': -71},
#     {'minute': 32, 'value': -11},
#     {'minute': 33, 'value': -43},
#     {'minute': 34, 'value': -38},
#     {'minute': 35, 'value': -27},
#     {'minute': 36, 'value': 5},
#     {'minute': 37, 'value': 0},
#     {'minute': 38, 'value': -16},
#     {'minute': 39, 'value': -90},
#     {'minute': 40, 'value': -84},
#     {'minute': 41, 'value': -46},
#     {'minute': 42, 'value': 33},
#     {'minute': 43, 'value': 27},
#     {'minute': 44, 'value': 5},
#     {'minute': 45, 'value': -16},
#     {'minute': 45.5, 'value': -14},
#     {'minute': 46, 'value': -16},
#     {'minute': 47, 'value': -16},
#     {'minute': 48, 'value': -16},
#     {'minute': 49, 'value': 0},
#     {'minute': 50, 'value': 0},
#     {'minute': 51, 'value': 5},
#     {'minute': 52, 'value': -11},
#     {'minute': 53, 'value': -16},
#     {'minute': 54, 'value': -100},
#     {'minute': 55, 'value': -100},
#     {'minute': 56, 'value': -100},
#     {'minute': 57, 'value': -24},
#     {'minute': 58, 'value': -41},
#     {'minute': 59, 'value': -5},
#     {'minute': 60, 'value': -33},
#     {'minute': 61, 'value': -22},
#     {'minute': 62, 'value': -16},
#     {'minute': 63, 'value': -5},
#     {'minute': 64, 'value': -81},
#     {'minute': 65, 'value': -100},
#     {'minute': 66, 'value': -100},
#     {'minute': 67, 'value': -100},
#     {'minute': 68, 'value': -3},
#     {'minute': 69, 'value': -14},
#     {'minute': 70, 'value': 19},
#     {'minute': 71, 'value': -41},
#     {'minute': 72, 'value': -52},
#     {'minute': 73, 'value': -60},
#     {'minute': 74, 'value': -43},
#     {'minute': 75, 'value': -16},
#     {'minute': 76, 'value': -11},
#     {'minute': 77, 'value': -11},
#     {'minute': 78, 'value': -27},
#     {'minute': 79, 'value': -52},
#     {'minute': 80, 'value': -57},
#     {'minute': 81, 'value': -57},
#     {'minute': 82, 'value': -33},
#     {'minute': 83, 'value': -11},
#     {'minute': 84, 'value': -11},
#     {'minute': 85, 'value': -16},
#     {'minute': 86, 'value': -38},
#     {'minute': 87, 'value': -27},
#     {'minute': 88, 'value': -41},
#     {'minute': 89, 'value': -19},
#     {'minute': 90, 'value': -24},
#     {'minute': 90.5, 'value': 6},
#     {'minute': 90.75, 'value': 0}],
#    'debugTitle': 'Using xT SA-version'},
#   'alternateModels': []}]

# %%
last_game = gameDe[4]

# %%
last_game.keys()
# Out:
# dict_keys(['shots', 'Periods'])

# %% [markdown]
# ### Get Shot Data of Player

# %%
last_game["shots"]
# Out:
# [{'id': 2603683539,
#   'eventType': 'Goal',
#   'teamId': 8568,
#   'playerId': 765466,
#   'playerName': 'Sebastian Szymanski',
#   'x': 86.352941176,
#   'y': 33.084999999999994,
#   'min': 4,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': True,
#   'blockedX': None,
#   'blockedY': None,
#   'goalCrossedY': 36.97375,
#   'goalCrossedZ': 0.4879999976,
#   'expectedGoals': 0.11487847566604614,
#   'expectedGoalsOnTarget': 0.3029,
#   'shotType': 'LeftFoot',
#   'situation': 'RegularPlay',
#   'period': 'FirstHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 0.21329365079365015,
#    'y': 0.12910052846560846,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Sebastian',
#   'lastName': 'Szymanski',
#   'fullName': 'Sebastian Szymanski',
#   'teamColor': '#ff2600'},
#  {'id': 2603687939,
#   'eventType': 'AttemptSaved',
#   'teamId': 8568,
#   'playerId': 402419,
#   'playerName': 'Przemyslaw Frankowski',
#   'x': 93.5,
#   'y': 43.790573243599994,
#   'min': 15,
#   'minAdded': None,
#   'isBlocked': True,
#   'isOnTarget': True,
#   'blockedX': 96.79824561320001,
#   'blockedY': 41.3678125,
#   'goalCrossedY': 33.8475,
#   'goalCrossedZ': 1.2199999940000001,
#   'expectedGoals': 0.06017984449863434,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'RightFoot',
#   'situation': 'RegularPlay',
#   'period': 'FirstHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 1.0403439153439162,
#    'y': 0.32275132116402117,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Przemyslaw',
#   'lastName': 'Frankowski',
#   'fullName': 'Przemyslaw Frankowski',
#   'teamColor': '#ff2600'},
#  {'id': 2603693059,
#   'eventType': 'Miss',
#   'teamId': 8269,
#   'playerId': 180660,
#   'playerName': 'Joan Simun Edmundsson',
#   'x': 92.8,
#   'y': 30.797499999999996,
#   'min': 28,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': False,
#   'blockedX': None,
#   'blockedY': None,
#   'goalCrossedY': 27.698571428000005,
#   'goalCrossedZ': 0.7127368386,
#   'expectedGoals': 0.02691986784338951,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'Header',
#   'situation': 'FromCorner',
#   'period': 'FirstHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 2,
#    'y': 0.11310718362610697,
#    'zoomRatio': 0.5998639763681837},
#   'isSavedOffLine': False,
#   'firstName': 'Joan Simun',
#   'lastName': 'Edmundsson',
#   'fullName': 'Joan Simun Edmundsson',
#   'teamColor': '#3060A8'},
#  {'id': 2603696653,
#   'eventType': 'Miss',
#   'teamId': 8568,
#   'playerId': 277460,
#   'playerName': 'Arkadiusz Milik',
#   'x': 98.535087719,
#   'y': 32.70374999999999,
#   'min': 29,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': False,
#   'blockedX': 101.9655172416,
#   'blockedY': 0,
#   'goalCrossedY': 0.7871090051999999,
#   'goalCrossedZ': 0.3595789456,
#   'expectedGoals': 0.36681824922561646,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'RightFoot',
#   'situation': 'RegularPlay',
#   'period': 'FirstHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 2,
#    'y': 0.010826487391787052,
#    'zoomRatio': 0.11381123072339044},
#   'isSavedOffLine': False,
#   'firstName': 'Arkadiusz',
#   'lastName': 'Milik',
#   'fullName': 'Arkadiusz Milik',
#   'teamColor': '#ff2600'},
#  {'id': 2603693893,
#   'eventType': 'AttemptSaved',
#   'teamId': 8568,
#   'playerId': 402419,
#   'playerName': 'Przemyslaw Frankowski',
#   'x': 95.15789473550001,
#   'y': 45.9625477669,
#   'min': 30,
#   'minAdded': None,
#   'isBlocked': True,
#   'isOnTarget': True,
#   'blockedX': 96.605263157,
#   'blockedY': 44.2810191037,
#   'goalCrossedY': 34.7625,
#   'goalCrossedZ': 1.2199999940000001,
#   'expectedGoals': 0.03461189940571785,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'LeftFoot',
#   'situation': 'RegularPlay',
#   'period': 'FirstHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 0.7982804232804226,
#    'y': 0.32275132116402117,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Przemyslaw',
#   'lastName': 'Frankowski',
#   'fullName': 'Przemyslaw Frankowski',
#   'teamColor': '#ff2600'},
#  {'id': 2603697533,
#   'eventType': 'Miss',
#   'teamId': 8568,
#   'playerId': 277460,
#   'playerName': 'Arkadiusz Milik',
#   'x': 96.0263157884,
#   'y': 33.61875,
#   'min': 39,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': False,
#   'blockedX': 98.0526315785,
#   'blockedY': 43.650445855,
#   'goalCrossedY': 48.8351592332,
#   'goalCrossedZ': 1.4254736772,
#   'expectedGoals': 0.08779732882976532,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'Header',
#   'situation': 'RegularPlay',
#   'period': 'FirstHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 0,
#    'y': 0.09608752119154165,
#    'zoomRatio': 0.25480009621606464},
#   'isSavedOffLine': False,
#   'firstName': 'Arkadiusz',
#   'lastName': 'Milik',
#   'fullName': 'Arkadiusz Milik',
#   'teamColor': '#ff2600'},
#  {'id': 2603697537,
#   'eventType': 'AttemptSaved',
#   'teamId': 8568,
#   'playerId': 402419,
#   'playerName': 'Przemyslaw Frankowski',
#   'x': 93.7,
#   'y': 41.5990625,
#   'min': 39,
#   'minAdded': None,
#   'isBlocked': True,
#   'isOnTarget': True,
#   'blockedX': 96.79824561320001,
#   'blockedY': 39.545000001,
#   'goalCrossedY': 34.68625,
#   'goalCrossedZ': 1.2199999940000001,
#   'expectedGoals': 0.0764651969075203,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'RightFoot',
#   'situation': 'RegularPlay',
#   'period': 'FirstHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 0.8184523809523807,
#    'y': 0.32275132116402117,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Przemyslaw',
#   'lastName': 'Frankowski',
#   'fullName': 'Przemyslaw Frankowski',
#   'teamColor': '#ff2600'},
#  {'id': 2603697565,
#   'eventType': 'AttemptSaved',
#   'teamId': 8568,
#   'playerId': 729731,
#   'playerName': 'Matty Cash',
#   'x': 97.7631578942,
#   'y': 27.194285714000003,
#   'min': 39,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': True,
#   'blockedX': 104.3362068966,
#   'blockedY': 31.78875,
#   'goalCrossedY': 33.31375,
#   'goalCrossedZ': 0.7705263120000001,
#   'expectedGoals': 0.04946630820631981,
#   'expectedGoalsOnTarget': 0.0242,
#   'shotType': 'Header',
#   'situation': 'RegularPlay',
#   'period': 'FirstHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 1.1815476190476193,
#    'y': 0.2038429396825397,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Matty',
#   'lastName': 'Cash',
#   'fullName': 'Matty Cash',
#   'teamColor': '#ff2600'},
#  {'id': 2603703007,
#   'eventType': 'Miss',
#   'teamId': 8568,
#   'playerId': 362212,
#   'playerName': 'Piotr Zielinski',
#   'x': 86.24558823480001,
#   'y': 34,
#   'min': 50,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': False,
#   'blockedX': None,
#   'blockedY': None,
#   'goalCrossedY': 28.370952380000002,
#   'goalCrossedZ': 2.551,
#   'expectedGoals': 0.15196539461612701,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'RightFoot',
#   'situation': 'FreeKick',
#   'period': 'SecondHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 2,
#    'y': 0.4531850096517753,
#    'zoomRatio': 0.6715167920359508},
#   'isSavedOffLine': False,
#   'firstName': 'Piotr',
#   'lastName': 'Zielinski',
#   'fullName': 'Piotr Zielinski',
#   'teamColor': '#ff2600'},
#  {'id': 2603704251,
#   'eventType': 'AttemptSaved',
#   'teamId': 8568,
#   'playerId': 1245669,
#   'playerName': 'Patryk Peda',
#   'x': 95.35087719170001,
#   'y': 35.9825,
#   'min': 54,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': True,
#   'blockedX': 103.8620689656,
#   'blockedY': 34.533750000000005,
#   'goalCrossedY': 33.2375,
#   'goalCrossedZ': 0.3659999982,
#   'expectedGoals': 0.11601250618696213,
#   'expectedGoalsOnTarget': 0.0578,
#   'shotType': 'LeftFoot',
#   'situation': 'RegularPlay',
#   'period': 'SecondHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 1.2017195767195774,
#    'y': 0.09682539634920634,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Patryk',
#   'lastName': 'Peda',
#   'fullName': 'Patryk Peda',
#   'teamColor': '#ff2600'},
#  {'id': 2603706853,
#   'eventType': 'AttemptSaved',
#   'teamId': 8568,
#   'playerId': 402419,
#   'playerName': 'Przemyslaw Frankowski',
#   'x': 77.9800970888,
#   'y': 47.714140124400004,
#   'min': 61,
#   'minAdded': None,
#   'isBlocked': True,
#   'isOnTarget': True,
#   'blockedX': 91.3,
#   'blockedY': 40.805714286,
#   'goalCrossedY': 32.0175,
#   'goalCrossedZ': 1.2199999940000001,
#   'expectedGoals': 0.014545807614922523,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'RightFoot',
#   'situation': 'RegularPlay',
#   'period': 'SecondHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 1.5244708994709,
#    'y': 0.32275132116402117,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Przemyslaw',
#   'lastName': 'Frankowski',
#   'fullName': 'Przemyslaw Frankowski',
#   'teamColor': '#ff2600'},
#  {'id': 2603708943,
#   'eventType': 'Goal',
#   'teamId': 8568,
#   'playerId': 557396,
#   'playerName': 'Adam Buksa',
#   'x': 100.1637931038,
#   'y': 36.440000000000005,
#   'min': 65,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': True,
#   'blockedX': None,
#   'blockedY': None,
#   'goalCrossedY': 36.135000000000005,
#   'goalCrossedZ': 0.2439999988,
#   'expectedGoals': 0.3510149121284485,
#   'expectedGoalsOnTarget': 0.7853,
#   'shotType': 'Header',
#   'situation': 'RegularPlay',
#   'period': 'SecondHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 0.4351851851851839,
#    'y': 0.06455026423280423,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Adam',
#   'lastName': 'Buksa',
#   'fullName': 'Adam Buksa',
#   'teamColor': '#ff2600'},
#  {'id': 2603710179,
#   'eventType': 'Miss',
#   'teamId': 8269,
#   'playerId': 180660,
#   'playerName': 'Joan Simun Edmundsson',
#   'x': 91.5,
#   'y': 33.00875,
#   'min': 68,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': False,
#   'blockedX': None,
#   'blockedY': None,
#   'goalCrossedY': 43.5103184664,
#   'goalCrossedZ': 1.60526315,
#   'expectedGoals': 0.026676464825868607,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'Header',
#   'situation': 'RegularPlay',
#   'period': 'SecondHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 0,
#    'y': 0.16879173454300214,
#    'zoomRatio': 0.39746303063927435},
#   'isSavedOffLine': False,
#   'firstName': 'Joan Simun',
#   'lastName': 'Edmundsson',
#   'fullName': 'Joan Simun Edmundsson',
#   'teamColor': '#3060A8'},
#  {'id': 2603717543,
#   'eventType': 'AttemptSaved',
#   'teamId': 8568,
#   'playerId': 689987,
#   'playerName': 'Jakub Piotrowski',
#   'x': 81.35873786479999,
#   'y': 20.5661146528,
#   'min': 84,
#   'minAdded': None,
#   'isBlocked': True,
#   'isOnTarget': True,
#   'blockedX': 91.7,
#   'blockedY': 26.111875,
#   'goalCrossedY': 34.68625,
#   'goalCrossedZ': 1.2199999940000001,
#   'expectedGoals': 0.0178599264472723,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'RightFoot',
#   'situation': 'RegularPlay',
#   'period': 'SecondHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 0.8184523809523807,
#    'y': 0.32275132116402117,
#    'zoomRatio': 1},
#   'isSavedOffLine': False,
#   'firstName': 'Jakub',
#   'lastName': 'Piotrowski',
#   'fullName': 'Jakub Piotrowski',
#   'teamColor': '#ff2600'},
#  {'id': 2603719329,
#   'eventType': 'Miss',
#   'teamId': 8568,
#   'playerId': 1003329,
#   'playerName': 'Filip Marchwinski',
#   'x': 100.1637931038,
#   'y': 45.3319745182,
#   'min': 88,
#   'minAdded': None,
#   'isBlocked': False,
#   'isOnTarget': False,
#   'blockedX': None,
#   'blockedY': None,
#   'goalCrossedY': 39.460952381999995,
#   'goalCrossedZ': 0.802631575,
#   'expectedGoals': 0.07512927800416946,
#   'expectedGoalsOnTarget': None,
#   'shotType': 'LeftFoot',
#   'situation': 'RegularPlay',
#   'period': 'SecondHalf',
#   'isOwnGoal': False,
#   'onGoalShot': {'x': 0,
#    'y': 0.14697648301156727,
#    'zoomRatio': 0.6921869548724447},
#   'isSavedOffLine': False,
#   'firstName': 'Filip',
#   'lastName': 'Marchwinski',
#   'fullName': 'Filip Marchwinski',
#   'teamColor': '#ff2600'}]

# %%
length = len(last_game["shots"])
length
# Out:
# 15

# %%
# shots = 0
# for i in range(length):
#     if last_game["shots"][i]["playerName"] == "Dusan Tadic":
#         print(str(last_game["shots"][i]["eventType"]) +
#                ", Dakika " +
#                  str(last_game["shots"][i]["min"]) +
#                  ", Konum " + 
#                  " X : " +
#                  str(last_game["shots"][i]["x"]) +
#                      " Y : " +
#                       str(last_game["shots"][i]["y"])
#                  )
#         shots = shots + 1

# shots

# %% [markdown]
# ### Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects

# We'll only use a vertical pitch for this tutorial
from mplsoccer import VerticalPitch

# %% [markdown]
# #### Pitch examples

# %%
# fig = plt.figure(figsize = (4,4), dpi = 100)
# ax = plt.subplot(111)

# pitch = VerticalPitch()

# pitch.draw(ax = ax)

# %%
# fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (8,5), dpi = 100)

# providers = ["opta", "statsbomb", "uefa"]
# for index, ax in enumerate(axes.flat):
#     pitch = VerticalPitch(
#         pitch_type = providers[index], 
#         axis = True, 
#         label = True, 
#         tick = True
#     )
#     pitch.draw(ax = ax)

#     # So we can view more ticks in the chart
#     ax.xaxis.set_major_locator(ticker.MultipleLocator(15))
#     ax.yaxis.set_major_locator(ticker.MultipleLocator(15))

#     ax.set_title(providers[index])

# plt.subplots_adjust(wspace = 0.75)

# %%
last_game["shots"][0]["expectedGoals"]
round(last_game["shots"][0]["expectedGoals"], 2)
# Out:
# 0.11

# %% [markdown]
# #### ShotMap

# %%
fig = plt.figure(figsize = (8,8), dpi = 100)
ax = plt.subplot(111)

colors = "red"

# Notice the extra parameters passed to the object
pitch = VerticalPitch(
    pitch_type = "uefa",
    half = False,
    axis = True, 
    label = False, 
    tick = False,
    pitch_color='grass',
    goal_type='box'
)

pitch.draw(ax = ax)

# Hypothetical shot.
for i in range(length):
    if last_game["shots"][i]["playerName"] == playername:
        ax.set_title(playername + " vs " + oppName1)
    if last_game["shots"][i]["playerName"] == playername and last_game["shots"][i]["eventType"] == "Goal":
        colors = "darkgreen"
        ax.scatter(last_game["shots"][i]["y"],last_game["shots"][i]["x"], s = 30, c=colors)
        ax.annotate(round(last_game["shots"][0]["expectedGoals"], 2), (last_game["shots"][i]["y"],last_game["shots"][i]["x"]), textcoords="offset points", xytext=(0, 5),  ha='center')
    if last_game["shots"][i]["playerName"] == playername and last_game["shots"][i]["eventType"] != "Goal":
        colors = "red"
        ax.scatter(last_game["shots"][i]["y"],last_game["shots"][i]["x"], s = 30, c=colors)
        ax.annotate(round(last_game["shots"][0]["expectedGoals"], 2), (last_game["shots"][i]["y"],last_game["shots"][i]["x"]), textcoords="offset points", xytext=(0, 5),  ha='center')
